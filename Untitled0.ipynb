# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/study/vision-model-playground
# Out:
# /content/drive/MyDrive/study/vision-model-playground

# %%
pwd
# Out:
# '/content/drive/MyDrive/study/vision-model-playground'

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/study/vision-model-playground/.git/

# %%
# !git clone https://github.com/while-true-study/vision-model-playground.git

# !git config --global user.email 'aodaod128@naver.com'
# !git config --global user.name 'while-true-study'
# Out:
# Cloning into 'vision-model-playground'...
# ...

# %%
# !git add .
# Out:
# error: 'vision-model-playground/' does not have a commit checked out
# fatal: adding files failed
